# %%
with open("foodie.txt", "r", encoding="utf-8") as file:
    text = file.read()

print(text)
# Out:
# I love trying different kinds of food from around the world.
# My favorite dishes are biryani, pizza, mutton keema, and masala dosa.
# I enjoy visiting new restaurants and exploring local street food.
# Spicy food is my favorite because it has rich flavors and exciting aromas.
# As a foodie, I like learning about different cuisines and cooking techniques.
# Desserts such as ice cream, brownies, and cheesecakes are my favorite treats.
# Food brings people together and creates wonderful memories.
